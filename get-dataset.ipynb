# %%
# https://research.google/resources/datasets/bengali-tts/
# https://www.openslr.org/53/

# %% [markdown]
# https://research.google/resources/datasets/bengali-tts/

# %%
# !wget https://www.openslr.org/resources/37/bn_bd.zip -O /home/ubuntu/bengali/google-dataset/bn_bd.zip
# Out:
# Will not apply HSTS. The HSTS database must be a regular and non-world-writable file.
# ERROR: could not open HSTS store at '/home/ubuntu/.wget-hsts'. HSTS will be disabled.
# --2023-09-13 13:32:31--  https://www.openslr.org/resources/37/bn_bd.zip
# Resolving www.openslr.org (www.openslr.org)... 46.101.158.64
# Connecting to www.openslr.org (www.openslr.org)|46.101.158.64|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: http://us.openslr.org/resources/37/bn_bd.zip [following]
# --2023-09-13 13:32:31--  http://us.openslr.org/resources/37/bn_bd.zip
# Resolving us.openslr.org (us.openslr.org)... 46.101.158.64
# Connecting to us.openslr.org (us.openslr.org)|46.101.158.64|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 586288792 (559M) [application/zip]
# Saving to: ‘/home/ubuntu/bengali/google-dataset/bn_bd.zip’
#
# /home/ubuntu/bengal 100%[===================>] 559.13M  17.2MB/s    in 32s
#
# ...

# %%
# !chmod 600 /home/ubuntu/.kaggle/kaggle.json

# %% [markdown]
# https://www.openslr.org/53/

# %%
!~/.local/bin/kaggle datasets download --help
# Out:
# ...
# usage: kaggle datasets download [-h] [-f FILE_NAME] [-p PATH] [-w] [--unzip]
#                                 [-o] [-q]
#                                 [dataset]
#
# options:
#   -h, --help            show this help message and exit
#   dataset               Dataset URL suffix in format <owner>/<dataset-name> (use "kaggle datasets list" to show options)
#   -f FILE_NAME, --file FILE_NAME
#                         File name, all files downloaded if not provided
#                         (use "kaggle datasets files -d <dataset>" to show options)
#   -p PATH, --path PATH  Folder where file(s) will be downloaded, defaults to current working directory
#   -w, --wp              Download files to current working path
#   --unzip               Unzip the downloaded file. Will delete the zip file when completed.
#   -o, --force           Skip check whether local version of file is up to date, force file download
# ...

# %%
!~/.local/bin/kaggle datasets download -d ksmcg90/bengali-asr-datasets -p /home/ubuntu/bengali/new-datasets/ --unzip
# Out:
# ...
# 100%|█████████████████████████████████████▉| 2.77G/2.77G [02:41<00:00, 20.5MB/s]
# 100%|██████████████████████████████████████| 2.77G/2.77G [02:41<00:00, 18.4MB/s]

# %%
from datasets import load_from_disk
dataset = load_from_disk("/home/ubuntu/bengali/new-datasets/fleurs_bn")

# %%
import pandas as pd
df = pd.DataFrame(dataset)

# %%
df.head()
# Out:
#      id  num_samples                                               path  \
# 0   813       163200  /root/.cache/huggingface/datasets/downloads/ex...
# 1    64       224640  /root/.cache/huggingface/datasets/downloads/ex...
# 2   327       224640  /root/.cache/huggingface/datasets/downloads/ex...
# 3  1433       149760  /root/.cache/huggingface/datasets/downloads/ex...
# 4  1038       136320  /root/.cache/huggingface/datasets/downloads/ex...
#
#                                                audio  \
# 0  {'path': 'train/10007728875760582479.wav', 'ar...
# 1  {'path': 'train/10027935128938619078.wav', 'ar...
# 2  {'path': 'train/10031075386419533084.wav', 'ar...
# 3  {'path': 'train/10032118353482869345.wav', 'ar...
# 4  {'path': 'train/10033964478741707062.wav', 'ar...
#
#                                             sentence  \
# 0  এক মাইলের কম থেকে শুরু করে বেশি দূরত্ব যা কিনা...
# 1  ব্রাজিলের জাতীয় কংগ্রেস সামাজিক বিবাহকে 10 বছ...
# ...

# %%
dataset1 = load_from_disk("/home/ubuntu/bengali/new-datasets/openslr_bn")

# %%
dataset1
# Out:
# Dataset({
#     features: ['path', 'audio', 'sentence'],
#     num_rows: 218703
# })

# %%
# !wget https://openslr.org/resources/53/asr_bengali_1.zip -O /home/ubuntu/bengali/new-datasets/asr_bengali_1.zip
# Out:
# Will not apply HSTS. The HSTS database must be a regular and non-world-writable file.
# ERROR: could not open HSTS store at '/home/ubuntu/.wget-hsts'. HSTS will be disabled.
# --2023-09-13 14:00:18--  https://openslr.org/resources/53/asr_bengali_1.zip
# Resolving openslr.org (openslr.org)... 46.101.158.64
# Connecting to openslr.org (openslr.org)|46.101.158.64|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: http://us.openslr.org/resources/53/asr_bengali_1.zip [following]
# --2023-09-13 14:00:19--  http://us.openslr.org/resources/53/asr_bengali_1.zip
# Resolving us.openslr.org (us.openslr.org)... 46.101.158.64
# Connecting to us.openslr.org (us.openslr.org)|46.101.158.64|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 906161405 (864M) [application/zip]
# Saving to: ‘/home/ubuntu/bengali/new-datasets/asr_bengali_1.zip’
#
# /home/ubuntu/bengal 100%[===================>] 864.18M  18.7MB/s    in 53s
#
# ...

# %%
# !unzip /home/ubuntu/bengali/new-datasets/asr_bengali_1.zip
# Out:
# Archive:  /home/ubuntu/bengali/new-datasets/asr_bengali_1.zip
#  extracting: asr_bengali/LICENSE
#  extracting: asr_bengali/utt_spk_text.tsv
#    creating: asr_bengali/data/10/
#  extracting: asr_bengali/data/10/10bc0e4df5.flac
#  extracting: asr_bengali/data/10/10bf36476a.flac
#  extracting: asr_bengali/data/10/10a1e52a65.flac
#  extracting: asr_bengali/data/10/1061a92111.flac
#  extracting: asr_bengali/data/10/10a1d256e8.flac
#  extracting: asr_bengali/data/10/10b2910f46.flac
#  extracting: asr_bengali/data/10/10c184e579.flac
#  extracting: asr_bengali/data/10/101f9bffd5.flac
#  extracting: asr_bengali/data/10/103943563a.flac
#  extracting: asr_bengali/data/10/10ee52a6bf.flac
#  extracting: asr_bengali/data/10/100871f757.flac
#  extracting: asr_bengali/data/10/1049a48d4b.flac
#  extracting: asr_bengali/data/10/101018e394.flac
#  extracting: asr_bengali/data/10/10819df2aa.flac
#  extracting: asr_bengali/data/10/10bdbd0fdd.flac
#  extracting: asr_bengali/data/10/10882efe53.flac
# ...

# %%
import librosa

# %%
# Read the FLAC file
audio, sr = librosa.load("/home/ubuntu/bengali/new-datasets/asr_bengali/data/10/100075b816.flac")

# Print the sample rate
print(sr)
# Out:
# 22050

# %%
import soundfile as sf

audio, sr = sf.read("/home/ubuntu/bengali/new-datasets/asr_bengali/data/10/100075b816.flac")

sf.write("output.wav", samplerate=sr, data=audio)

# %%
# https://huggingface.co/datasets/google/fleurs/viewer/bn_in/train

# %%
from datasets import load_dataset
dataset = load_dataset("google/fleurs", "bn_in")
# Out:
# ...
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'num_samples', 'path', 'audio', 'transcription', 'raw_transcription', 'gender', 'lang_id', 'language', 'lang_group_id'],
#         num_rows: 3006
#     })
#     validation: Dataset({
#         features: ['id', 'num_samples', 'path', 'audio', 'transcription', 'raw_transcription', 'gender', 'lang_id', 'language', 'lang_group_id'],
#         num_rows: 402
#     })
#     test: Dataset({
#         features: ['id', 'num_samples', 'path', 'audio', 'transcription', 'raw_transcription', 'gender', 'lang_id', 'language', 'lang_group_id'],
#         num_rows: 920
#     })
# })

# %%
dataset = load_dataset("/home/ubuntu/.cache/huggingface/datasets/google___fleurs/bn_in/2.0.0/af82dbec419a815084fa63ebd5d5a9f24a6e9acdf9887b9e3b8c6bbd64e0b7ac")
# Out:
# ...
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'num_samples', 'path', 'audio', 'transcription', 'raw_transcription', 'gender', 'lang_id', 'language', 'lang_group_id'],
#         num_rows: 3006
#     })
#     validation: Dataset({
#         features: ['id', 'num_samples', 'path', 'audio', 'transcription', 'raw_transcription', 'gender', 'lang_id', 'language', 'lang_group_id'],
#         num_rows: 402
#     })
#     test: Dataset({
#         features: ['id', 'num_samples', 'path', 'audio', 'transcription', 'raw_transcription', 'gender', 'lang_id', 'language', 'lang_group_id'],
#         num_rows: 920
#     })
# })

# %%
df = pd.DataFrame(dataset['train'])

# %%
df['audio'][1]
# Out:
# {'path': 'train/10027935128938619078.wav',
#  'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          3.65304947e-03,  4.69088554e-05, -5.51939011e-05]),
#  'sampling_rate': 16000}
